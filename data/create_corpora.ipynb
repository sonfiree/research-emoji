# %% [markdown]
# Make corpora from data got from emojidictionary and emojipedia webpages

# %%
import matplotlib.pyplot as plt
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

import os
import tensorflow as tf
from tensorflow.python.framework import ops
import pickle as pk
import gensim.models as gs
import numpy as np
import random
import re
# Internal dependencies
from model import Emoji2Vec
from trainer import Trainer
from batcher import BatchNegSampler

# %%
emojipedia_data = "../data/emojis_all.txt"
emojidict_data = "../data/emojis_emojidictionary_new.txt"

emojipedia_corpora_name = "../data/emojipedia"
emojidict_corpora_name = "../data/emojidict"

word2vec_file = "../data/word2vec/GoogleNews-vectors-negative300.bin"

# %%
def get_pos_samples(file):
    names_to_emojis = {}
    positive_samples = []
    with open(file, "r") as file:
        lines = file.readlines()
        for line in lines:
            defs = re.findall(r"\'(.+?)\'", line)
            line = line.split()
            name_words = []
            for i in range(1, len(line)):
                name_words.append(line[i].lower())
                if '[' in line[i+1]:
                    break
            name = ' '.join(name_words)
            names_to_emojis[name] = line[0].lower()
            for def_ in defs:
                positive_samples.append((line[0].lower(), def_, True))
    return names_to_emojis, positive_samples

# %%
names_to_emojis, positive_samples = get_pos_samples(emojipedia_data)

# %%
w2v = gs.KeyedVectors.load_word2vec_format(word2vec_file, binary=True)

# %%
counts = {}
for word, item in w2v.vocab.items():
    counts[word] = item.count

# %%
alphabet = 'abcdefghijklmnopqrstuvwxyz'

# %%
lower_counts = {}
lower_to_origin = {}
words = []
for word, value in counts.items():
    if np.any([w not in alphabet for w in word.lower()]):
        continue
            
    changed = False
    if word.lower() in lower_counts:
        lower_counts[word.lower()] = max(lower_counts[word.lower()], value)
        changed = True
    else:
        lower_counts[word.lower()] = value
        words.append(word.lower())
    if word.lower() not in lower_to_origin or changed:
        lower_to_origin[word.lower()] = word

# %%
freq_and_word = lambda item: item[::-1]
most_frequent = sorted(lower_counts.items(), key=freq_and_word, reverse=True)

# %%
len(words)
# Out:
# 699957

# %%
def get_neg_samples(names_to_emojis, positive_samples):
    negative_samples = []
    for emoji in names_to_emojis.values():
        random.shuffle(positive_samples)
        pos_samples_emoji = [x[1] for x in positive_samples if x[0] == emoji]
        emoji_keywords = []
        for x in pos_samples_emoji:
            emoji_keywords.extend([word for word in x.split() if len(word) > 2])
        count_generated = 0
#         for sample in positive_samples:
#             num_matches = len([x for x in sample[1].split() if sample[1].split() in emoji_keywords])
#             if num_matches > 0:
#                 continue
#             negative_samples.append((emoji, sample[1], False))
#             count_generated += 1
#             if count_generated > 500:
#                 break
        for i in range(200):
            for j in range(1, 4):
                negative_sample = []
                while True:
                    word = random.choice(words)
                    if word in emoji_keywords:
                        continue
                    negative_sample.append(word)
                    if len(negative_sample) == j:
                        break
                negative_samples.append((emoji, ' '.join(negative_sample), False))
    return negative_samples

# %%
len(names_to_emojis)
# Out:
# 1452

# %%
1452*600
# Out:
# 871200

# %%
def make_corpora(data, corpora_filename):
    names_to_emojis, positive_samples = get_pos_samples(data)
    random.shuffle(positive_samples)
    negative_samples = get_neg_samples(names_to_emojis, positive_samples)
    random.shuffle(negative_samples)
    
    with open("{}_positive.txt".format(corpora_filename), "w") as file:
        for i in range(len(positive_samples)):
            for j in range(3):
                file.write(str(positive_samples[i][j]))
                file.write('\t')
            file.write('\n')
        
    with open("{}_negative.txt".format(corpora_filename), "w") as file:
        for i in range(len(negative_samples)):
            for j in range(3):
                file.write(str(negative_samples[i][j]))
                file.write('\t')
            file.write('\n')
        
    return names_to_emojis, positive_samples, negative_samples

# %%
names_to_emojis, positive_samples, negative_samples = make_corpora(emojipedia_data, emojipedia_corpora_name)
#x = make_corpora(emojidict_data, emojidict_corpora_name)
# Out:
# ({'tractor': '🚜',
#   'pirate flag': '🏴\u200d☠️',
#   'flag burkina faso': '🇧🇫',
#   'flag sri lanka': '🇱🇰',
#   'middle finger': '🖕',
#   'robot face': '🤖',
#   'couple with heart: man, man': '👨\u200d❤️\u200d👨',
#   'flag in hole': '⛳',
#   'hot pepper': '🌶️',
#   'carp streamer': '🎏',
#   'waving hand sign': '👋',
#   'clock face six o’clock': '🕕',
#   'honeybee': '🐝',
#   'small blue diamond': '🔹',
#   'beach with umbrella': '🏖️',
#   'lady beetle': '🐞',
#   'flag belgium': '🇧🇪',
#   'anchor': '⚓',
#   'man police officer': '👮\u200d♂️',
#   'flag são tomé &amp; príncipe': '🇸🇹',
#   'sagittarius': '♐',
#   'bookmark tabs': '📑',
#   'flag somalia': '🇸🇴',
#   'drum with drumsticks': '\U0001f941',
#   'horse racing': '🏇',
#   'worried face': '😟',
#   'peanuts': '\U0001f95c',
#   'bacon': '\U0001f953',
#   'chipmunk': '🐿️',
#   'white sun behind cloud with rain': '🌦️',
#   'lock with ink pen': '🔏',
#   'boxing glove': '\U0001f94a',
#   'neutral face': '😐',
#   'clock face eleven o’clock': '🕚',
#   'convenience store': '🏪',
#   'money with wings': '💸',
#   'tent': '⛺',
#   'shrug ¯\\_(ツ)_/¯': '\U0001f937',
#   'white flower': '💮',
#   'input symbol for symbols': '🔣',
#   'flag nicaragua': '🇳🇮',
#   'peach': '🍑',
#   'flag pakistan': '🇵🇰',
#   'face screaming in fear': '😱',
#   'scales': '⚖️',
#   'flag azerbaijan': '🇦🇿',
#   'heavy multiplication x': '✖️',
#   'ship': '🚢',
#   'man judge': '👨\u200d⚖️',
#   'lower left fountain pen': '🖋️',
#   'gear': '⚙️',
#   'flag norway': '🇳🇴',
#   'input symbol for latin letters': '🔤',
#   'skier': '⛷️',
#   'chequered flag': '🏁',
#   'flag aruba': '🇦🇼',
#   'black spade suit': '♠️',
#   'customs': '🛃',
#   'flag singapore': '🇸🇬',
#   'seat': '💺',
#   'flag vietnam': '🇻🇳',
#   'japanese dolls': '🎎',
#   'kissing face with smiling eyes': '😙',
#   'ticket': '🎫',
#   'police car': '🚓',
#   'flag moldova': '🇲🇩',
#   'flag turks &amp; caicos islands': '🇹🇨',
#   'squared cool': '🆒',
#   'keycap digit six': '6️⃣',
#   'face with head-bandage': '🤕',
#   'fox face': '\U0001f98a',
#   'metro': '🚇',
#   'no pedestrians': '🚷',
#   'man bouncing ball': '⛹️\u200d♂️',
#   'black heart': '\U0001f5a4',
#   'thunder cloud and rain': '⛈️',
#   'libra': '♎',
#   'pear': '🍐',
#   'handshake': '\U0001f91d',
#   'woman detective': '🕵️\u200d♀️',
#   'candle': '🕯️',
#   'sailboat': '⛵',
#   'squared katakana sa': '🈂️',
#   'flag greece': '🇬🇷',
#   'door': '🚪',
#   'man playing handball': '\U0001f93e\u200d♂️',
#   'clock face one o’clock': '🕐',
#   'mother christmas': '\U0001f936',
#   'flag austria': '🇦🇹',
#   'flag british indian ocean territory': '🇮🇴',
#   'dragon': '🐉',
#   'flag macau sar china': '🇲🇴',
#   'warning sign': '⚠️',
#   'blue book': '📘',
#   'flag botswana': '🇧🇼',
#   'man firefighter': '👨\u200d🚒',
#   'wastebasket': '🗑️',
#   'bank': '🏦',
#   'flag guatemala': '🇬🇹',
#   'crown': '👑',
#   'raised hand': '✋',
#   'dress': '👗',
#   'family: man, woman, girl, girl': '👨\u200d👩\u200d👧\u200d👧',
#   'eagle': '\U0001f985',
#   'trolleybus': '🚎',
#   'speak-no-evil monkey': '🙊',
#   'joystick': '🕹️',
#   'man frowning': '🙍\u200d♂️',
#   'flag martinique': '🇲🇶',
#   'circled latin capital letter m': 'ⓜ️',
#   'oncoming taxi': '🚖',
#   'ram': '🐏',
#   'woman wearing turban': '👳\u200d♀️',
#   'thinking face': '🤔',
#   'flag algeria': '🇩🇿',
#   'wrench': '🔧',
#   'flag montenegro': '🇲🇪',
#   'flag turkey': '🇹🇷',
#   'violin': '🎻',
#   'flag tristan da cunha': '🇹🇦',
#   'arrow pointing rightwards then curving upwards': '⤴️',
#   'eyes': '👀',
#   'black telephone': '☎️',
#   'face with medical mask': '😷',
#   'key': '🔑',
#   'direct hit': '🎯',
#   'jeans': '👖',
#   'prince': '\U0001f934',
#   'eggplant': '🍆',
#   'man guard': '💂\u200d♂️',
#   'anger symbol': '💢',
#   'microphone': '🎤',
#   'yellow heart': '💛',
#   'man': '👨',
#   'lion face': '🦁',
#   'banknote with pound sign': '💷',
#   'flag denmark': '🇩🇰',
#   'stadium': '🏟️',
#   'flag palau': '🇵🇼',
#   'back with leftwards arrow above': '🔙',
#   'imp': '👿',
#   'white heavy check mark': '✅',
#   'amphora': '🏺',
#   'steaming bowl': '🍜',
#   'men wrestling': '\U0001f93c\u200d♂️',
#   'flag lebanon': '🇱🇧',
#   'smoking symbol': '🚬',
#   'sunflower': '🌻',
#   'butterfly': '\U0001f98b',
#   'helmet with white cross': '⛑️',
#   'waving white flag': '🏳️',
#   'heavy plus sign': '➕',
#   'shaved ice': '🍧',
#   'crossed flags': '🎌',
#   'bath': '🛀',
#   'white exclamation mark ornament': '❕',
#   'flag burundi': '🇧🇮',
#   'smiling cat face with heart-shaped eyes': '😻',
#   'closed book': '📕',
#   'sheep': '🐑',
#   'compression': '🗜️',
#   'flag belize': '🇧🇿',
#   'flag french guiana': '🇬🇫',
#   'flag madagascar': '🇲🇬',
#   'slightly frowning face': '🙁',
#   'flag niger': '🇳🇪',
#   'woman swimming': '🏊\u200d♀️',
#   'hot beverage': '☕',
#   'pedestrian': '🚶',
#   'clapping hands sign': '👏',
#   'multiple musical notes': '🎶',
#   'bento box': '🍱',
#   'sports medal': '🏅',
#   'squared new': '🆕',
#   'fishing pole and fish': '🎣',
#   'person with blond hair': '👱',
#   'flag uruguay': '🇺🇾',
#   'pill': '💊',
#   'flag mongolia': '🇲🇳',
#   'ferry': '⛴️',
#   'flag congo - brazzaville': '🇨🇬',
#   'flag puerto rico': '🇵🇷',
#   'spiral calendar pad': '🗓️',
#   'downwards black arrow': '⬇️',
#   'rainbow flag': '🏳️\u200d🌈',
#   'studio microphone': '🎙️',
#   'alembic': '⚗️',
#   'french fries': '🍟',
#   'page facing up': '📄',
#   'squared cjk unified ideograph-6e80': '🈵',
#   'electric plug': '🔌',
#   'grimacing face': '😬',
#   'hamster face': '🐹',
#   'link symbol': '🔗',
#   'woman gesturing ok': '🙆\u200d♀️',
#   'cancer': '♋',
#   'pager': '📟',
#   'flag trinidad &amp; tobago': '🇹🇹',
#   'horse face': '🐴',
#   'woman astronaut': '👩\u200d🚀',
#   'cow face': '🐮',
#   'circled ideograph accept': '🉑',
#   'airplane departure': '🛫',
#   'lollipop': '🍭',
#   'runner': '🏃',
#   'smiling cat face with open mouth': '😺',
#   'file cabinet': '🗄️',
#   'clockwise rightwards and leftwards open circle arrows': '🔁',
#   'bus stop': '🚏',
#   'man gesturing no': '🙅\u200d♂️',
#   'hammer and pick': '⚒️',
#   'police cars revolving light': '🚨',
#   'black left-pointing double triangle': '⏪',
#   'woman facepalming': '\U0001f926\u200d♀️',
#   'revolving hearts': '💞',
#   'hushed face': '😯',
#   'black universal recycling symbol': '♻️',
#   'first quarter moon symbol': '🌓',
#   'stop sign': '\U0001f6d1',
#   'man tipping hand': '💁\u200d♂️',
#   'eyeglasses': '👓',
#   'man lifting weights': '🏋️\u200d♂️',
#   'second place medal': '\U0001f948',
#   'flag portugal': '🇵🇹',
#   'ox': '🐂',
#   'guitar': '🎸',
#   'smiling face with halo': '😇',
#   'face with stuck-out tongue and winking eye': '😜',
#   'raised fist': '✊',
#   'flag antigua &amp; barbuda': '🇦🇬',
#   'droplet': '💧',
#   'flag côte d’ivoire': '🇨🇮',
#   'bug': '🐛',
#   'down-pointing small red triangle': '🔽',
#   'waving black flag': '🏴',
#   'racing car': '🏎️',
#   'lock': '🔒',
#   'writing hand': '✍️',
#   'tiger face': '🐯',
#   'menorah with nine branches': '🕎',
#   'family: man, man, girl, girl': '👨\u200d👨\u200d👧\u200d👧',
#   'kiss': '💏',
#   'flag tunisia': '🇹🇳',
#   'relieved face': '😌',
#   'flag switzerland': '🇨🇭',
#   'oden': '🍢',
#   'man bowing': '🙇\u200d♂️',
#   'family: woman, girl, boy': '👩\u200d👧\u200d👦',
#   'confused face': '😕',
#   'black right-pointing triangle': '▶️',
#   'fingers crossed': '\U0001f91e',
#   'flag new zealand': '🇳🇿',
#   'european post office': '🏤',
#   'clock face nine-thirty': '🕤',
#   'man biking': '🚴\u200d♂️',
#   'family: woman, woman, girl, boy': '👩\u200d👩\u200d👧\u200d👦',
#   'volleyball': '🏐',
#   'horse': '🐎',
#   'flag mexico': '🇲🇽',
#   'person with folded hands': '🙏',
#   'sun with face': '🌞',
#   'black small square': '▪️',
#   'flushed face': '😳',
#   'flag british virgin islands': '🇻🇬',
#   'satellite antenna': '📡',
#   'family': '👪',
#   'pushpin': '📌',
#   'wolf face': '🐺',
#   'woman firefighter': '👩\u200d🚒',
#   'bridge at night': '🌉',
#   'black scissors': '✂️',
#   'womans clothes': '👚',
#   'european castle': '🏰',
#   'dizzy face': '😵',
#   'squared sos': '🆘',
#   'military medal': '🎖️',
#   'sunset over buildings': '🌇',
#   'closed mailbox with raised flag': '📫',
#   'ice hockey stick and puck': '🏒',
#   'triangular ruler': '📐',
#   'flag nauru': '🇳🇷',
#   'shopping bags': '🛍️',
#   'pouting cat face': '😾',
#   'construction worker': '👷',
#   'rhinoceros': '\U0001f98f',
#   'flag cambodia': '🇰🇭',
#   'woman walking': '🚶\u200d♀️',
#   'chains': '⛓️',
#   'suspension railway': '🚟',
#   'flag sweden': '🇸🇪',
#   'negative squared latin capital letter a': '🅰️',
#   'twisted rightwards arrows': '🔀',
#   'couch and lamp': '🛋️',
#   'clock face eight o’clock': '🕗',
#   'snowman': '☃️',
#   'nail polish': '💅',
#   'swimmer': '🏊',
#   'telescope': '🔭',
#   'tram car': '🚋',
#   'woman with bunny ears': '👯',
#   'flag qatar': '🇶🇦',
#   'tulip': '🌷',
#   'ice cream': '🍨',
#   'gorilla': '\U0001f98d',
#   'upwards black arrow': '⬆️',
#   'weight lifter': '🏋️',
#   'astonished face': '😲',
#   'top hat': '🎩',
#   'flag lithuania': '🇱🇹',
#   'minidisc': '💽',
#   'speaker with cancellation stroke': '🔇',
#   'clock face ten o’clock': '🕙',
#   'closed umbrella': '🌂',
#   'crystal ball': '🔮',
#   'large blue diamond': '🔷',
#   'high brightness symbol': '🔆',
#   'man mechanic': '👨\u200d🔧',
#   'house building': '🏠',
#   'alien monster': '👾',
#   'film frames': '🎞️',
#   'part alternation mark': '〽️',
#   'rabbit face': '🐰',
#   'raised back of hand': '\U0001f91a',
#   'heavy large circle': '⭕',
#   'control knobs': '🎛️',
#   'man with turban': '👳',
#   'mountain cableway': '🚠',
#   'envelope': '✉️',
#   'pile of poo': '💩',
#   'japanese ogre': '👹',
#   'man playing water polo': '\U0001f93d\u200d♂️',
#   'barber pole': '💈',
#   'derelict house building': '🏚️',
#   'flag cocos (keeling) islands': '🇨🇨',
#   'spider': '🕷️',
#   'package': '📦',
#   'small airplane': '🛩️',
#   'flag falkland islands': '🇫🇰',
#   'evergreen tree': '🌲',
#   'hammer and wrench': '🛠️',
#   'tear-off calendar': '📆',
#   'flag guernsey': '🇬🇬',
#   'squared katakana koko': '🈁',
#   'japanese symbol for beginner': '🔰',
#   'camping': '🏕️',
#   'memo': '📝',
#   'flag malta': '🇲🇹',
#   'flag curaçao': '🇨🇼',
#   'new moon with face': '🌚',
#   'flag south africa': '🇿🇦',
#   'flag malawi': '🇲🇼',
#   'flag ceuta &amp; melilla': '🇪🇦',
#   'lower left crayon': '🖍️',
#   'wind chime': '🎐',
#   'squared cjk unified ideograph-7533': '🈸',
#   'money-mouth face': '🤑',
#   'do not litter symbol': '🚯',
#   'flag philippines': '🇵🇭',
#   'wilted flower': '\U0001f940',
#   'confounded face': '😖',
#   'keycap digit zero': '0️⃣',
#   'family: man, woman, girl, boy': '👨\u200d👩\u200d👧\u200d👦',
#   'clock face five o’clock': '🕔',
#   'bottle with popping cork': '🍾',
#   'flag cameroon': '🇨🇲',
#   'prayer beads': '📿',
#   'black diamond suit': '♦️',
#   'banknote with euro sign': '💶',
#   'negative squared latin capital letter b': '🅱️',
#   'hole': '🕳️',
#   'carousel horse': '🎠',
#   'flag honduras': '🇭🇳',
#   'tumbler glass': '\U0001f943',
#   'north east arrow': '↗️',
#   'thought balloon': '💭',
#   'dog face': '🐶',
#   'cocktail glass': '🍸',
#   'flag new caledonia': '🇳🇨',
#   'flag guam': '🇬🇺',
#   'family: man, girl, boy': '👨\u200d👧\u200d👦',
#   'shortcake': '🍰',
#   'flag solomon islands': '🇸🇧',
#   'beer mug': '🍺',
#   'wedding': '💒',
#   'flag slovenia': '🇸🇮',
#   'rolling on the floor laughing': '\U0001f923',
#   'face with look of triumph': '😤',
#   'level slider': '🎚️',
#   'put litter in its place symbol': '🚮',
#   'womens symbol': '🚺',
#   'electric torch': '🔦',
#   'croissant': '\U0001f950',
#   'smiling face with horns': '😈',
#   'white sun with small cloud': '🌤️',
#   'arrow pointing rightwards then curving downwards': '⤵️',
#   'hatching chick': '🐣',
#   'atom symbol': '⚛️',
#   'white up pointing index': '☝️',
#   'clock face twelve-thirty': '🕧',
#   'bicyclist': '🚴',
#   'black square for stop': '⏹️',
#   'oncoming automobile': '🚘',
#   'crescent moon': '🌙',
#   'statue of liberty': '🗽',
#   'flag vanuatu': '🇻🇺',
#   'flag wales (gb-wls)': '🏴\U000e0067\U000e0062\U000e0077\U000e006c\U000e0073\U000e007f',
#   'flag iraq': '🇮🇶',
#   'woman raising hand': '🙋\u200d♀️',
#   'white square button': '🔳',
#   'speaker with one sound wave': '🔉',
#   'fog': '🌫️',
#   'mountain bicyclist': '🚵',
#   'trumpet': '🎺',
#   'woman surfing': '🏄\u200d♀️',
#   'leftwards arrow with hook': '↩️',
#   'slightly smiling face': '🙂',
#   'pot of food': '🍲',
#   'monkey face': '🐵',
#   'heavy exclamation mark symbol': '❗',
#   'tangerine': '🍊',
#   'potato': '\U0001f954',
#   'necktie': '👔',
#   'flag paraguay': '🇵🇾',
#   'squared vs': '🆚',
#   'hospital': '🏥',
#   'building construction': '🏗️',
#   'virgo': '♍',
#   'flag slovakia': '🇸🇰',
#   'aquarius': '♒',
#   'large red circle': '🔴',
#   'copyright sign': '©️',
#   'men with bunny ears partying': '👯\u200d♂️',
#   'lizard': '\U0001f98e',
#   'flag united states': '🇺🇸',
#   'purse': '👛',
#   'poultry leg': '🍗',
#   'umbrella on ground': '⛱️',
#   'honey pot': '🍯',
#   'family: man, woman, boy': '👨\u200d👩\u200d👦',
#   'monorail': '🚝',
#   'last quarter moon symbol': '🌗',
#   'vertical traffic light': '🚦',
#   'automated teller machine': '🏧',
#   'soccer ball': '⚽',
#   'flag american samoa': '🇦🇸',
#   'flag barbados': '🇧🇧',
#   'down-pointing red triangle': '🔻',
#   'flag dominica': '🇩🇲',
#   'bride with veil': '👰',
#   'spouting whale': '🐳',
#   'sun behind cloud': '⛅',
#   'flag united kingdom': '🇬🇧',
#   'rabbit': '🐇',
#   'rainbow': '🌈',
#   'passenger ship': '🛳️',
#   'flag jordan': '🇯🇴',
#   'clinking beer mugs': '🍻',
#   'thumbs up sign': '👍',
#   'exclamation question mark': '⁉️',
#   'haircut': '💇',
#   'avocado': '\U0001f951',
#   'pensive face': '😔',
#   'clock face seven o’clock': '🕖',
#   'flag heard &amp; mcdonald islands': '🇭🇲',
#   'flag kosovo': '🇽🇰',
#   'dove of peace': '🕊️',
#   'flag saudi arabia': '🇸🇦',
#   'flag jamaica': '🇯🇲',
#   'green heart': '💚',
#   'diamond shape with a dot inside': '💠',
#   'fork and knife with plate': '🍽️',
#   'flag wallis &amp; futuna': '🇼🇫',
#   'woman running': '🏃\u200d♀️',
#   'pig nose': '🐽',
#   'hotel': '🏨',
#   'party popper': '🎉',
#   'railway track': '🛤️',
#   'flag ireland': '🇮🇪',
#   'flag diego garcia': '🇩🇬',
#   'school satchel': '🎒',
#   'cloud with tornado': '🌪️',
#   'performing arts': '🎭',
#   'flag spain': '🇪🇸',
#   'mans shoe': '👞',
#   'flag south korea': '🇰🇷',
#   'sneezing face': '\U0001f927',
#   'two men holding hands': '👬',
#   'synagogue': '🕍',
#   'peace symbol': '☮️',
#   'alarm clock': '⏰',
#   'ballot box with ballot': '🗳️',
#   'flag samoa': '🇼🇸',
#   'open file folder': '📂',
#   'beating heart': '💓',
#   'extraterrestrial alien': '👽',
#   'man swimming': '🏊\u200d♂️',
#   'field hockey stick and ball': '🏑',
#   'printer': '🖨️',
#   'pancakes': '\U0001f95e',
#   'books': '📚',
#   'flag north korea': '🇰🇵',
#   'latin cross': '✝️',
#   'dash symbol': '💨',
#   'negative squared latin capital letter p': '🅿️',
#   'japanese castle': '🏯',
#   'man juggling': '\U0001f939\u200d♂️',
#   'hot springs': '♨️',
#   'grinning cat face with smiling eyes': '😸',
#   'waxing crescent moon symbol': '🌒',
#   'restroom': '🚻',
#   'earth globe europe-africa': '🌍',
#   'orthodox cross': '☦️',
#   'right-pointing magnifying glass': '🔎',
#   'flag iceland': '🇮🇸',
#   'orange book': '📙',
#   'cat face with wry smile': '😼',
#   'squared ok': '🆗',
#   'flag cuba': '🇨🇺',
#   'flag equatorial guinea': '🇬🇶',
#   'rightwards arrow with hook': '↪️',
#   'person bowing deeply': '🙇',
#   'medium white circle': '⚪',
#   'television': '📺',
#   'flag pitcairn islands': '🇵🇳',
#   'rolled-up newspaper': '🗞️',
#   'white smiling face': '☺️',
#   'flag taiwan': '🇹🇼',
#   'pineapple': '🍍',
#   'passport control': '🛂',
#   'ribbon': '🎀',
#   'flag timor-leste': '🇹🇱',
#   'flag comoros': '🇰🇲',
#   'loudly crying face': '😭',
#   'bell with cancellation stroke': '🔕',
#   'sparkles': '✨',
#   'flag guyana': '🇬🇾',
#   'man rowing boat': '🚣\u200d♂️',
#   't-shirt': '👕',
#   'frame with picture': '🖼️',
#   'south east arrow': '↘️',
#   'flag mayotte': '🇾🇹',
#   'flag tokelau': '🇹🇰',
#   'input symbol for numbers': '🔢',
#   'no entry': '⛔',
#   'wrapped present': '🎁',
#   'flag congo - kinshasa': '🇨🇩',
#   'flag montserrat': '🇲🇸',
#   'billiards': '🎱',
#   'family: man, man, boy, boy': '👨\u200d👨\u200d👦\u200d👦',
#   'family: man, boy, boy': '👨\u200d👦\u200d👦',
#   'first quarter moon with face': '🌛',
#   'glowing star': '🌟',
#   'cityscape': '🏙️',
#   'pig': '🐖',
#   'boar': '🐗',
#   'flag st. martin': '🇲🇫',
#   'fish': '🐟',
#   'last quarter moon with face': '🌜',
#   'inbox tray': '📥',
#   'woman pilot': '👩\u200d✈️',
#   'squid': '\U0001f991',
#   'bird': '🐦',
#   'flag israel': '🇮🇱',
#   'trackball': '🖲️',
#   'face with cowboy hat': '\U0001f920',
#   'thermometer': '🌡️',
#   'martial arts uniform': '\U0001f94b',
#   'sleeping accommodation': '🛌',
#   'flag sierra leone': '🇸🇱',
#   'tiger': '🐅',
#   'construction sign': '🚧',
#   'large blue circle': '🔵',
#   'rose': '🌹',
#   'floppy disk': '💾',
#   'cloud with lightning': '🌩️',
#   'bow and arrow': '🏹',
#   'flag senegal': '🇸🇳',
#   'classical building': '🏛️',
#   'family: man, woman, girl': '👨\u200d👩\u200d👧',
#   'family: woman, woman, boy': '👩\u200d👩\u200d👦',
#   'star of david': '✡️',
#   'surfer': '🏄',
#   'flag benin': '🇧🇯',
#   'pouting face': '😡',
#   'woman playing water polo': '\U0001f93d\u200d♀️',
#   'black heart suit': '♥️',
#   'boy': '👦',
#   'flag guinea': '🇬🇳',
#   'banknote with yen sign': '💴',
#   'custard': '🍮',
#   'family: woman, woman, boy, boy': '👩\u200d👩\u200d👦\u200d👦',
#   'water buffalo': '🐃',
#   'face palm': '\U0001f926',
#   'frowning face with open mouth': '😦',
#   'deciduous tree': '🌳',
#   'flag thailand': '🇹🇭',
#   'gem stone': '💎',
#   'woman bowing': '🙇\u200d♀️',
#   'flag st. barthélemy': '🇧🇱',
#   'women wrestling': '\U0001f93c\u200d♀️',
#   'smirking face': '😏',
#   'flexed biceps': '💪',
#   'ballot box with check': '☑️',
#   'water polo': '\U0001f93d',
#   'woman rowing boat': '🚣\u200d♀️',
#   'airplane arriving': '🛬',
#   'up-pointing red triangle': '🔺',
#   'flag andorra': '🇦🇩',
#   'flag guinea-bissau': '🇬🇼',
#   'keycap number sign': '#️⃣',
#   'antenna with bars': '📶',
#   'man pouting': '🙎\u200d♂️',
#   'flag libya': '🇱🇾',
#   'page with curl': '📃',
#   'women with bunny ears partying': '👯\u200d♀️',
#   'hundred points symbol': '💯',
#   'straight ruler': '📏',
#   'donut': '🍩',
#   'bikini': '👙',
#   'mobile phone with rightwards arrow at left': '📲',
#   'curry and rice': '🍛',
#   'snowflake': '❄️',
#   'clock face four-thirty': '🕟',
#   'no smoking symbol': '🚭',
#   'goat': '🐐',
#   'keycap ten': '🔟',
#   'black medium small square': '◾',
#   'tram': '🚊',
#   'flag réunion': '🇷🇪',
#   'squared cl': '🆑',
#   'man golfing': '🏌️\u200d♂️',
#   'baby symbol': '🚼',
#   'cheese wedge': '🧀',
#   'flag svalbard &amp; jan mayen': '🇸🇯',
#   'incoming envelope': '📨',
#   'flag netherlands': '🇳🇱',
#   'family: man, man, girl': '👨\u200d👨\u200d👧',
#   'oncoming bus': '🚍',
#   'desert island': '🏝️',
#   'mountain railway': '🚞',
#   'chart with downwards trend': '📉',
#   'open book': '📖',
#   'newspaper': '📰',
#   'clock face six-thirty': '🕡',
#   'flag kenya': '🇰🇪',
#   'squared cjk unified ideograph-7121': '🈚',
#   'flag dominican republic': '🇩🇴',
#   'footprints': '👣',
#   'clown face': '\U0001f921',
#   'flag gibraltar': '🇬🇮',
#   'baby': '👶',
#   'squared cjk unified ideograph-5408': '🈴',
#   'christmas tree': '🎄',
#   'face with cold sweat': '😓',
#   'sake bottle and cup': '🍶',
#   'banknote with dollar sign': '💵',
#   'circled ideograph secret': '㊙️',
#   'snake': '🐍',
#   'whale': '🐋',
#   'fearful face': '😨',
#   'face with rolling eyes': '🙄',
#   'kissing face with closed eyes': '😚',
#   'disappointed face': '😞',
#   'girl': '👧',
#   'clock face eleven-thirty': '🕦',
#   'flag guadeloupe': '🇬🇵',
#   'flag ecuador': '🇪🇨',
#   'golfer': '🏌️',
#   'sparkling heart': '💖',
#   'train': '🚆',
#   'clipboard': '📋',
#   'ear': '👂',
#   'kaaba': '🕋',
#   'flag mauritius': '🇲🇺',
#   'keycap digit one': '1️⃣',
#   'flag rwanda': '🇷🇼',
#   'flag georgia': '🇬🇪',
#   'information desk person': '💁',
#   'round pushpin': '📍',
#   'heart decoration': '💟',
#   'woman singer': '👩\u200d🎤',
#   'man mountain biking': '🚵\u200d♂️',
#   'full moon symbol': '🌕',
#   'money bag': '💰',
#   'keycap digit five': '5️⃣',
#   'bomb': '💣',
#   'burrito': '🌯',
#   'panda face': '🐼',
#   'heart with arrow': '💘',
#   'man in tuxedo': '\U0001f935',
#   'baby angel': '👼',
#   'no one under eighteen symbol': '🔞',
#   'shrimp': '\U0001f990',
#   'broken heart': '💔',
#   'flag bhutan': '🇧🇹',
#   'flag peru': '🇵🇪',
#   'pick': '⛏️',
#   'rosette': '🏵️',
#   'no entry sign': '🚫',
#   'wine glass': '🍷',
#   'sleepy face': '😪',
#   'person frowning': '🙍',
#   'happy person raising one hand': '🙋',
#   'fireworks': '🎆',
#   'weary cat face': '🙀',
#   'balloon': '🎈',
#   'low brightness symbol': '🔅',
#   'scorpion': '🦂',
#   'flag bahamas': '🇧🇸',
#   'ok hand sign': '👌',
#   'chart with upwards trend': '📈',
#   'top with upwards arrow above': '🔝',
#   'flag bahrain': '🇧🇭',
#   'flag grenada': '🇬🇩',
#   'camera': '📷',
#   'older woman': '👵',
#   'person doing cartwheel': '\U0001f938',
#   'winking face': '😉',
#   'family: woman, woman, girl, girl': '👩\u200d👩\u200d👧\u200d👧',
#   'foggy': '🌁',
#   'flag kazakhstan': '🇰🇿',
#   'person with pouting face': '🙎',
#   'unicorn face': '🦄',
#   'fork and knife': '🍴',
#   'flag finland': '🇫🇮',
#   'man student': '👨\u200d🎓',
#   'bear face': '🐻',
#   'white question mark ornament': '❔',
#   'kissing cat face with closed eyes': '😽',
#   'spoon': '\U0001f944',
#   'flag st. helena': '🇸🇭',
#   'woman judge': '👩\u200d⚖️',
#   'man raising hand': '🙋\u200d♂️',
#   'flag western sahara': '🇪🇭',
#   'tongue': '👅',
#   'envelope with downwards arrow above': '📩',
#   'teacup without handle': '🍵',
#   'growing heart': '💗',
#   'woman pouting': '🙎\u200d♀️',
#   'playing card black joker': '🃏',
#   'railway car': '🚃',
#   'man pilot': '👨\u200d✈️',
#   'flag st. vincent &amp; grenadines': '🇻🇨',
#   'movie camera': '🎥',
#   'black question mark ornament': '❓',
#   'unamused face': '😒',
#   'aerial tramway': '🚡',
#   'fountain': '⛲',
#   'fuel pump': '⛽',
#   'flag maldives': '🇲🇻',
#   'keycap digit four': '4️⃣',
#   'first place medal': '\U0001f947',
#   'face with open mouth': '😮',
#   'cat': '🐈',
#   'man cook': '👨\u200d🍳',
#   'owl': '\U0001f989',
#   'flag el salvador': '🇸🇻',
#   'dango': '🍡',
#   'flag morocco': '🇲🇦',
#   'woman guard': '💂\u200d♀️',
#   'input symbol for latin small letters': '🔡',
#   'ant': '🐜',
#   'womans sandal': '👡',
#   'bathtub': '🛁',
#   'flag hong kong sar china': '🇭🇰',
#   'microscope': '🔬',
#   'dolphin': '🐬',
#   'face massage': '💆',
#   'face with open mouth and cold sweat': '😰',
#   'flag nigeria': '🇳🇬',
#   'flag niue': '🇳🇺',
#   'trade mark sign': '™️',
#   'flag mali': '🇲🇱',
#   'scooter': '\U0001f6f4',
#   'busts in silhouette': '👥',
#   'open hands sign': '👐',
#   'circus tent': '🎪',
#   'trident emblem': '🔱',
#   'vulcan salute': '🖖',
#   'optical disc': '💿',
#   'speaker with three sound waves': '🔊',
#   'toilet': '🚽',
#   'mobile phone': '📱',
#   'cloud with snow': '🌨️',
#   'flag bouvet island': '🇧🇻',
#   'squared cjk unified ideograph-7a7a': '🈳',
#   'woman factory worker': '👩\u200d🏭',
#   'place of worship': '🛐',
#   'clock face seven-thirty': '🕢',
#   'leaf fluttering in wind': '🍃',
#   'sign of the horns': '🤘',
#   'flag mauritania': '🇲🇷',
#   'ambulance': '🚑',
#   'cucumber': '\U0001f952',
#   'flag scotland (gb-sct)': '🏴\U000e0067\U000e0062\U000e0073\U000e0063\U000e0074\U000e007f',
#   'flag indonesia': '🇮🇩',
#   'heavy division sign': '➗',
#   'headphone': '🎧',
#   'hourglass': '⌛',
#   'gemini': '♊',
#   'expressionless face': '😑',
#   'flag christmas island': '🇨🇽',
#   'oncoming police car': '🚔',
#   'end with leftwards arrow above': '🔚',
#   'flag estonia': '🇪🇪',
#   'cooked rice': '🍚',
#   'squared cjk unified ideograph-6709': '🈶',
#   'flag malaysia': '🇲🇾',
#   'flag swaziland': '🇸🇿',
#   'eight pointed black star': '✴️',
#   'spider web': '🕸️',
#   'bar chart': '📊',
#   'flag antarctica': '🇦🇶',
#   'palm tree': '🌴',
#   'heavy heart exclamation mark ornament': '❣️',
#   'man gesturing ok': '🙆\u200d♂️',
#   'crab': '🦀',
#   'saxophone': '🎷',
#   'black up-pointing double triangle': '⏫',
#   'flag french polynesia': '🇵🇫',
#   'fallen leaf': '🍂',
#   'taurus': '♉',
#   'tokyo tower': '🗼',
#   'clapper board': '🎬',
#   'leftwards black arrow': '⬅️',
#   'motor boat': '🛥️',
#   'tanabata tree': '🎋',
#   'motor scooter': '\U0001f6f5',
#   'hugging face': '🤗',
#   'mouse face': '🐭',
#   'frog face': '🐸',
#   'flag panama': '🇵🇦',
#   'flag zimbabwe': '🇿🇼',
#   'womans boots': '👢',
#   'paw prints': '🐾',
#   'chicken': '🐔',
#   'woman student': '👩\u200d🎓',
#   'video game': '🎮',
#   'woman biking': '🚴\u200d♀️',
#   'black sun with rays': '☀️',
#   'tropical fish': '🐠',
#   'flag central african republic': '🇨🇫',
#   'leo': '♌',
#   'flag u.s. outlying islands': '🇺🇲',
#   'bat': '\U0001f987',
#   'minibus': '🚐',
#   'water wave': '🌊',
#   'circled ideograph congratulation': '㊗️',
#   'flag brazil': '🇧🇷',
#   'persevering face': '😣',
#   'clock face twelve o’clock': '🕛',
#   'black right-pointing double triangle': '⏩',
#   'clockwise downwards and upwards open circle arrows': '🔃',
#   'e-mail symbol': '📧',
#   'poodle': '🐩',
#   'postbox': '📮',
#   'cherry blossom': '🌸',
#   'flag isle of man': '🇮🇲',
#   'taco': '🌮',
#   'closed mailbox with lowered flag': '📪',
#   'thumbs down sign': '👎',
#   'cow': '🐄',
#   'running shirt with sash': '🎽',
#   'koala': '🐨',
#   'flag egypt': '🇪🇬',
#   'skull': '💀',
#   'wheel of dharma': '☸️',
#   'confetti ball': '🎊',
#   'handbag': '👜',
#   'up down arrow': '↕️',
#   'ferris wheel': '🎡',
#   'nerd face': '🤓',
#   'flag micronesia': '🇫🇲',
#   'double exclamation mark': '‼️',
#   'right anger bubble': '🗯️',
#   'meat on bone': '🍖',
#   'wheelchair symbol': '♿',
#   'syringe': '💉',
#   'speaker': '🔈',
#   'flag costa rica': '🇨🇷',
#   'label': '🏷️',
#   'department store': '🏬',
#   'family: woman, girl': '👩\u200d👧',
#   'waxing gibbous moon symbol': '🌔',
#   'cherries': '🍒',
#   'person raising both hands in celebration': '🙌',
#   'anguished face': '😧',
#   'american football': '🏈',
#   'birthday cake': '🎂',
#   'face throwing a kiss': '😘',
#   'notebook with decorative cover': '📔',
#   'flag åland islands': '🇦🇽',
#   'squared cjk unified ideograph-6307': '🈯',
#   'roller coaster': '🎢',
#   'aries': '♈',
#   'woman scientist': '👩\u200d🔬',
#   'flag myanmar (burma)': '🇲🇲',
#   'cat face with tears of joy': '😹',
#   'white medium square': '◻️',
#   'lying face': '\U0001f925',
#   'flag vatican city': '🇻🇦',
#   'flag japan': '🇯🇵',
#   'star and crescent': '☪️',
#   'open lock': '🔓',
#   'heart eyes': '😍',
#   'flag clipperton island': '🇨🇵',
#   'clock face three-thirty': '🕞',
#   'man farmer': '👨\u200d🌾',
#   'purple heart': '💜',
#   'moyai': '🗿',
#   'new moon symbol': '🌑',
#   'mens symbol': '🚹',
#   'lipstick': '💄',
#   'family: man, girl': '👨\u200d👧',
#   'shower': '🚿',
#   'baby bottle': '🍼',
#   'high-speed train with bullet nose': '🚅',
#   'woman frowning': '🙍\u200d♀️',
#   'zipper-mouth face': '🤐',
#   'man detective': '🕵️\u200d♂️',
#   'flag united arab emirates': '🇦🇪',
#   'herb': '🌿',
#   'taxi': '🚕',
#   'woman construction worker': '👷\u200d♀️',
#   'front-facing baby chick': '🐥',
#   'flag eritrea': '🇪🇷',
#   'face with no good gesture': '🙅',
#   'flag laos': '🇱🇦',
#   'flag poland': '🇵🇱',
#   'flag serbia': '🇷🇸',
#   'flag south sudan': '🇸🇸',
#   'snail': '🐌',
#   'hibiscus': '🌺',
#   'mahjong tile red dragon': '🀄',
#   'flag brunei': '🇧🇳',
#   'woman lifting weights': '🏋️\u200d♀️',
#   'cactus': '🌵',
#   'heavy minus sign': '➖',
#   'blond-haired man': '👱\u200d♂️',
#   'lower left ballpoint pen': '🖊️',
#   'face with ok gesture': '🙆',
#   'white frowning face': '☹️',
#   'see-no-evil monkey': '🙈',
#   'flag liberia': '🇱🇷',
#   'clock face eight-thirty': '🕣',
#   'potable water symbol': '🚰',
#   'flag uzbekistan': '🇺🇿',
#   'fried shrimp': '🍤',
#   'spiral shell': '🐚',
#   'man cartwheeling': '\U0001f938\u200d♂️',
#   'graduation cap': '🎓',
#   'corn': '🌽',
#   'collision symbol': '💥',
#   'pouch': '👝',
#   'love hotel': '🏩',
#   'umbrella with rain drops': '☔',
#   'cat face': '🐱',
#   'white left pointing backhand index': '👈',
#   'videocassette': '📼',
#   'couple with heart: woman, woman': '👩\u200d❤️\u200d👩',
#   'flag united nations': '🇺🇳',
#   'musical score': '🎼',
#   'rowboat': '🚣',
#   'flag anguilla': '🇦🇮',
#   'cooking': '🍳',
#   'speaking head in silhouette': '🗣️',
#   'juggling': '\U0001f939',
#   'elephant': '🐘',
#   'two hearts': '💕',
#   'church': '⛪',
#   'flag ethiopia': '🇪🇹',
#   'chestnut': '🌰',
#   'left luggage': '🛅',
#   'family: woman, woman, girl': '👩\u200d👩\u200d👧',
#   'calendar': '📅',
#   'woman getting haircut': '💇\u200d♀️',
#   'squared up with exclamation mark': '🆙',
#   'blowfish': '🐡',
#   'kimono': '👘',
#   'pencil': '✏️',
#   'couple with heart': '💑',
#   'satellite': '🛰️',
#   'sleeping face': '😴',
#   'personal computer': '💻',
#   'small orange diamond': '🔸',
#   'snowman without snow': '⛄',
#   'father christmas': '🎅',
#   'candy': '🍬',
#   'dromedary camel': '🐪',
#   'flag liechtenstein': '🇱🇮',
#   'red heart': '❤️',
#   'turkey': '🦃',
#   'house buildings': '🏘️',
#   'face with stuck-out tongue and tightly-closed eyes': '😝',
#   'stopwatch': '⏱️',
#   'drooling face': '\U0001f924',
#   'flag colombia': '🇨🇴',
#   'flag papua new guinea': '🇵🇬',
#   'racing motorcycle': '🏍️',
#   'fire': '🔥',
#   ...},
#  [('✔️', 'Tick', True),
#   ('🇭🇺', 'Hungarian Flag', True),
#   ('🇮🇶', 'Iraqi Flag', True),
#   ('🇧🇧', 'Bajan Flag', True),
#   ('🆑', 'Squared CL', True),
#   ('👷', 'Construction Worker', True),
#   ('🇨🇽', 'Christmas Island Flag', True),
#   ('🕹️', 'Joystick', True),
#   ('🇵🇬', 'PNG Flag', True),
#   ('🖍️', 'Lower Left Crayon', True),
#   ('👨\u200d🍳', 'Man Cook', True),
#   ('🔕', 'Notifications', True),
#   ('🈸', '申', True),
#   ('😧', 'Pained Face', True),
#   ('🌐', 'Globified', True),
#   ('🌜', 'Last Quarter Moon With Face', True),
#   ('🚷', 'No People', True),
#   ('🇺🇿', 'flag Uzbekistan', True),
#   ('🏴\U000e0067\U000e0062\U000e0077\U000e006c\U000e0073\U000e007f',
#    'Red Dragon',
#    True),
#   ('🚓', 'Side Of Police Car', True),
#   ('🎲', 'Dice', True),
#   ('☑️', 'Checkbox', True),
#   ('🇱🇮', 'flag Liechtenstein', True),
#   ('🍝', 'Pasta', True),
#   ('⚰️', 'Funeral', True),
#   ('🎭', 'Theatre Logo', True),
#   ('🇦🇷', 'Argentinian Flag', True),
#   ('📲', 'Mobile Phone With Rightwards Arrow at Left', True),
#   ('🇬🇬', 'flag Guernsey', True),
#   ('😡', 'Mad Face', True),
#   ('🈲', 'Forbid', True),
#   ('☺️', 'White Smiling Face', True),
#   ('🏳️', 'Waving White Flag', True),
#   ('⛽', 'Petrol Pump', True),
#   ('✅', 'Green Check Mark', True),
#   ('💚', 'Green Heart', True),
#   ('🙇', 'Dogeza', True),
#   ('🇱🇧', 'Lebanese Flag', True),
#   ('💃', 'Salsa Dancer', True),
#   ('👲', 'Man With Gua Pi Mao', True),
#   ('🎞️', 'Film Frames', True),
#   ('👙', 'Swimsuit', True),
#   ('📦', 'Box', True),
#   ('🆗', 'Square', True),
#   ('🛠️', 'Hammer and Wrench', True),
#   ('🎸', 'Bass Guitar', True),
#   ('💡', 'Light Bulb', True),
#   ('🇰🇿', 'flag Kazakhstan', True),
#   ('👢', 'Knee High Boots', True),
#   ('📆', 'Desk Calendar', True),
#   ('\U0001f922', 'Nauseated Face', True),
#   ('🎻', 'World’s Smallest Violin', True),
#   ('👚', 'Blouse', True),
#   ('🌯', 'Wrap', True),
#   ('🗳️', 'Ballot Box With Ballot', True),
#   ('🌌', 'Stars', True),
#   ('🚼', 'Baby Change Symbol', True),
#   ('📓', 'Notebook', True),
#   ('🍰', 'Shortcake', True),
#   ('🇨🇨', 'flag Cocos (Keeling) Islands', True),
#   ('🇰🇷', 'flag South Korea', True),
#   ('🎉', 'Party Popper', True),
#   ('🌏', 'Earth Globe Asia-Australia', True),
#   ('🉑', 'Circled Ideograph Accept', True),
#   ('😹', 'Laughing Cat', True),
#   ('🎖️', 'Medallion', True),
#   ('🚸', 'Children Crossing', True),
#   ('🐆', 'African Leopard', True),
#   ('🕵️', 'Sleuth', True),
#   ('🕣', 'Clock Eight-Thirty', True),
#   ('\U0001f93d', 'Water Polo', True),
#   ('✌️', 'V Sign', True),
#   ('⚖️', 'Scales of Justice', True),
#   ('🐗', 'Boar', True),
#   ('🔬', 'Magnify', True),
#   ('🔍', 'Magnifier', True),
#   ('👗', 'Skirt', True),
#   ('😵', 'Cross Eyes Face', True),
#   ('🇯🇵', 'Regional Indicator Symbol Letters JP', True),
#   ('🇸🇱', 'Sierra Leonean Flag', True),
#   ('🔥', 'Fire', True),
#   ('🏴\U000e0067\U000e0062\U000e0077\U000e006c\U000e0073\U000e007f',
#    'Welsh Flag',
#    True),
#   ('🇧🇭', 'Bahrani Flag', True),
#   ('⬅️', 'Arrow Pointing Left', True),
#   ('⛲', 'Water Feature', True),
#   ('😈', 'Smiling Face With Horns', True),
#   ('🤑', 'Rich', True),
#   ('🎑', 'Harvest Moon', True),
#   ('\U0001f93e\u200d♀️', 'Woman Playing Handball', True),
#   ('🛐', 'Place of Worship', True),
#   ('🙍', 'Person Frowning', True),
#   ('🎐', 'Furin', True),
#   ('📲', 'Pointing To Phone', True),
#   ('✏️', 'Pencil', True),
#   ('⏱️', 'Stopwatch', True),
#   ('✈️', 'Plane', True),
#   ('⚡', 'Lightning Bolt', True),
#   ('📻', 'Radio', True),
#   ('🌀', 'Cyclone', True),
#   ('😱', 'Home Alone', True),
#   ('🇨🇫', 'Central African Flag', True),
#   ('📶', 'Antenna With Bars', True),
#   ('🕒', 'Clock Three O’Clock', True),
#   ('🚣', 'Rowing', True),
#   ('🍑', 'Bottom', True),
#   ('👨\u200d👩\u200d👦\u200d👦', 'Family: Man, Woman, Boy, Boy', True),
#   ('\U0001f98e', 'Lizard', True),
#   ('🎈', 'Red Balloon', True),
#   ('📇', 'System Card', True),
#   ('🇵🇷', 'Puerto Rican Flag', True),
#   ('🏺', 'Vase', True),
#   ('🍜', 'Noodles With Chopsticks', True),
#   ('🌄', 'Sunrise', True),
#   ('🚓', 'Cop Car', True),
#   ('💬', 'Chat Bubble', True),
#   ('🇩🇯', 'flag Djibouti', True),
#   ('💋', 'Kiss Mark', True),
#   ('👑', 'Crown', True),
#   ('🇻🇺', 'Ni-Vanuatu\\xa0Flag', True),
#   ('🔨', 'Claw Hammer', True),
#   ('🌿', 'Crop', True),
#   ('👬', 'Gay Couple', True),
#   ('🙋', 'Answering Question', True),
#   ('👤', 'Bust in Silhouette', True),
#   ('🗣️', 'Mansplaining', True),
#   ('👖', 'Trousers', True),
#   ('🔡', 'Input Symbol for Latin Small Letters', True),
#   ('🎁', 'Birthday Present', True),
#   ('👨', 'Moustache Man', True),
#   ('🔮', 'Psychic', True),
#   ('🙏', 'High Five', True),
#   ('💁', 'Sassy Girl', True),
#   ('🐹', 'Hamster', True),
#   ('🍡', 'Pink White Green Balls', True),
#   ('🎿', 'Skiing', True),
#   ('\U0001f93c', 'Wrestlers', True),
#   ('💄', 'Lip Gloss', True),
#   ('🇩🇿', 'Algerian Flag', True),
#   ('🇪🇬', 'flag Egypt', True),
#   ('🐣', 'Chick Hatching', True),
#   ('📂', 'Open Folder', True),
#   ('👸', 'Girl With Crown', True),
#   ('🍲', 'Bowl Of Food', True),
#   ('👩\u200d👩\u200d👧\u200d👧', 'Family: Woman, Woman, Girl, Girl', True),
#   ('⛄', 'Frosty The Snowman', True),
#   ('💸', 'Money With Wings', True),
#   ('👎', 'Thumbs Down', True),
#   ('🇹🇰', 'flag Tokelau', True),
#   ('🈚', 'Squared CJK Unified Ideograph-7121', True),
#   ('📬', 'Open Mailbox', True),
#   ('🏦', 'Bakkureru', True),
#   ('👨\u200d👨\u200d👧\u200d👦', 'Family: Man, Man, Girl, Boy', True),
#   ('⛱️', 'Umbrella on Ground', True),
#   ('📬', 'Open Mailbox With Raised Flag', True),
#   ('👱', 'Blonde', True),
#   ('🕵️\u200d♂️', 'Man Detective', True),
#   ('🇬🇱', 'flag Greenland', True),
#   ('🍼', 'Baby Bottle', True),
#   ('🐤', 'Baby Chick', True),
#   ('3️⃣', 'Keycap Digit Three', True),
#   ('😿', 'Crying Cat Face', True),
#   ('🔥', 'Lit', True),
#   ('🔟', 'Number 10', True),
#   ('🐞', 'Ladybird', True),
#   ('🈹', 'Squared CJK Unified Ideograph-5272', True),
#   ('🔋', 'Battery', True),
#   ('🏺', 'Amphora', True),
#   ('🐮', 'Happy Cow', True),
#   ('🐛', 'Centipede', True),
#   ('🐲', 'Dragon Face', True),
#   ('🇰🇷', 'Regional Indicator Symbol Letters KR', True),
#   ('😠', 'Grumpy Face', True),
#   ('📃', 'Page With Curl', True),
#   ('🇱🇹', 'Lithuanian Flag', True),
#   ('🍑', 'Peach', True),
#   ('🛀', 'Bath', True),
#   ('👉', 'Right Pointing Backhand Index', True),
#   ('🕊️', 'Dove of Peace', True),
#   ('🎯', 'Direct Hit', True),
#   ('🎮', 'Wii U', True),
#   ('🏣', 'Japanese Postal Mark', True),
#   ('🎖️', 'Medal', True),
#   ('💉', 'Needle', True),
#   ('🎢', 'Theme Park', True),
#   ('😩', 'Weary Face', True),
#   ('😃', 'Smiley Face', True),
#   ('🔋', 'AA Battery', True),
#   ('🇨🇫', 'flag Central African Republic', True),
#   ('🕌', 'Domed Roof', True),
#   ('🗾', 'Silhouette of Japan', True),
#   ('✳️', 'Eight Spoked Asterisk', True),
#   ('🇰🇲', 'Comoran Flag', True),
#   ('🚪', 'Door', True),
#   ('🚉', 'Train Platform', True),
#   ('🌮', 'Taco', True),
#   ('🇬🇼', 'flag Guinea-Bissau', True),
#   ('\U0001f921', 'Scary Clown', True),
#   ('\U0001f98b', 'Butterfly', True),
#   ('💼', 'Suitcase', True),
#   ('🎌', 'Two Flags', True),
#   ('🔊', 'Speaker With Three Sound Waves', True),
#   ('😻', 'Smiling Cat Face With Heart-Shaped Eyes', True),
#   ('\U0001f91a', 'Backhand', True),
#   ('😡', 'Red Face', True),
#   ('😂', 'Laughing Tears', True),
#   ('👨\u200d👨\u200d👦', 'Family: Man, Man, Boy', True),
#   ('🇩🇰', 'Danish Flag', True),
#   ('🕦', 'Clock Eleven-Thirty', True),
#   ('🌊', 'Sea', True),
#   ('🏂', 'Snowboarding', True),
#   ('💺', 'Train Seat', True),
#   ('♥️', 'Hearts', True),
#   ('🚓', 'Police Car', True),
#   ('🎌', 'Crossed Flags', True),
#   ('\U0001f925', 'Liar', True),
#   ('🇬🇮', 'flag Gibraltar', True),
#   ('💇\u200d♂️', 'Man Getting Haircut', True),
#   ('↔️', 'Left Right Arrow', True),
#   ('\U0001f927', 'Gesundheit', True),
#   ('🎓', 'University', True),
#   ('\U0001f940', 'Drooping Flower', True),
#   ('😉', 'Winking Face', True),
#   ('🍁', 'Maple', True),
#   ('😤', 'Mad Face', True),
#   ('😑', 'Straight Face', True),
#   ('🇰🇮', 'I-Kiribati Flag', True),
#   ('🚱', 'Non-Potable Water Symbol', True),
#   ('🗃️', 'Card File Box', True),
#   ('😤', 'Face With Look of Triumph', True),
#   ('🙋', 'Happy Person Raising One Hand', True),
#   ('👨\u200d👩\u200d👦', 'Family: Man, Woman, Boy', True),
#   ('⛄', 'Snowman Without Snow', True),
#   ('😙', 'Kissing Face With Smiling Eyes', True),
#   ('🐱', 'Kitten', True),
#   ('😬', 'Grimacing Face', True),
#   ('🎌', 'Two Flags', True),
#   ('🇨🇳', 'flag China', True),
#   ('🚖', 'Oncoming Taxi', True),
#   ('🏈', 'Superbowl', True),
#   ('🌏', 'World', True),
#   ('👽', 'ET', True),
#   ('🌹', 'Rose', True),
#   ('👁️', 'Single Eye', True),
#   ('🇱🇨', 'flag St. Lucia', True),
#   ('💾', '3.5″ Disk', True),
#   ('⬜', 'White Large Square', True),
#   ('🇳🇱', 'flag Netherlands', True),
#   ('\U0001f950', 'Croissant', True),
#   ('👩\u200d👩\u200d👧', 'Lesbian family with child', True),
#   ('😋', 'Goofy', True),
#   ('⛩️', 'Shinto Shrine', True),
#   ('🇸🇱', 'flag Sierra Leone', True),
#   ('🚞', 'Funicular', True),
#   ('👩\u200d👩\u200d👧\u200d👦', 'Lesbian family', True),
#   ('🏵️', 'Rosette', True),
#   ('📤', 'Outbox', True),
#   ('🌱', 'Sprout', True),
#   ('🚘', 'Apple Car', True),
#   ('▫️', 'White Small Square', True),
#   ('🇺🇿', 'Uzbek Flag', True),
#   ('👏', 'Clapping', True),
#   ('🎠', 'Fairground', True),
#   ('🔗', 'Linked Chain', True),
#   ('🆙', 'Squared Up With Exclamation Mark', True),
#   ('🇧🇼', 'Batswana Flag', True),
#   ('🇸🇬', 'flag Singapore', True),
#   ('〽️', 'M', True),
#   ('🔱', 'Trident', True),
#   ('👨\u200d🏭', 'Man Factory Worker', True),
#   ('🏍️', 'Motorbike', True),
#   ('🖍️', 'Lower Left Crayon', True),
#   ('💠', 'Diamond Shape With a Dot Inside', True),
#   ('🇯🇵', 'flag Japan', True),
#   ('🎋', 'Wish Tree', True),
#   ('🚸', 'Kids Crossing', True),
#   ('🏍️', 'Racing Motorcycle', True),
#   ('🔭', 'Stargazing', True),
#   ('🗂️', 'Card Index Dividers', True),
#   ('🇴🇲', 'flag Oman', True),
#   ('🐃', 'Buffalo', True),
#   ('🌂', 'Closed Umbrella', True),
#   ('🇧🇲', 'flag Bermuda', True),
#   ('💕', 'Small Hearts', True),
#   ('🖖', 'Spock', True),
#   ('🐂', 'Oxen', True),
#   ('🙏', 'Praying Hands', True),
#   ('📨', 'Fast Envelope', True),
#   ('💆', 'Massaging', True),
#   ('🇬🇮', 'Gibraltarian Flag', True),
#   ('🇿🇼', 'Zim Flag', True),
#   ('😧', 'Anguished Face', True),
#   ('📯', 'Bugle', True),
#   ('🚰', 'Thirst', True),
#   ('🎿', 'Ski and Ski Boot', True),
#   ('🇮🇨', 'flag Canary Islands', True),
#   ('😁', 'Grinning Face With Smiling Eyes', True),
#   ('🌡️', 'Thermometer', True),
#   ('🇯🇵', 'Japanese Flag', True),
#   ('🌝', 'Smiley Moon', True),
#   ('🐎', 'Galloping Horse', True),
#   ('💈', 'Barber Pole', True),
#   ('👢', 'Cowgirl Boots', True),
#   ('🇧🇳', 'flag Brunei', True),
#   ('💈', 'Barbers Stripes', True),
#   ('🌡️', 'Temperature', True),
#   ('👩\u200d👩\u200d👧', 'Family: Woman, Woman, Girl', True),
#   ('🔢', 'Numbers', True),
#   ('📇', 'Index Card', True),
#   ('🎋', 'Tanabata Tree', True),
#   ('🐾', 'Kitten Paw Prints', True),
#   ('🇰🇳', 'flag St. Kitts &amp; Nevis', True),
#   ('🚕', 'Side Of Taxi', True),
#   ('👩\u200d🏭', 'Woman Factory Worker', True),
#   ('\U0001f6f5', 'Motor Scooter', True),
#   ('👦', 'Boy', True),
#   ('🌤️', 'White Sun With Small Cloud', True),
#   ('💗', 'Growing Heart', True),
#   ('📝', 'Note', True),
#   ('👄', 'Lips', True),
#   ('🌭', 'Hot Dog', True),
#   ('➿', 'Double Curling Loop', True),
#   ('🎿', 'Skis', True),
#   ('👱', 'Person With Blond Hair', True),
#   ('🇲🇰', 'Macedonian Flag', True),
#   ('👩\u200d👧\u200d👧', 'Only parent', True),
#   ('🏎️', 'Formula One', True),
#   ('👄', 'Speaking', True),
#   ('🐁', 'Rodent', True),
#   ('✍️', 'Writing Hand', True),
#   ('👩\u200d👦\u200d👦', 'Mother', True),
#   ('🎑', 'Tsukimi', True),
#   ('🐰', 'Easter Bunny', True),
#   ('\U0001f954', 'Potato', True),
#   ('💌', 'Heart Envelope', True),
#   ('👣', 'Footprints', True),
#   ('🐝', 'Honeybee', True),
#   ('🎤', 'Microphone', True),
#   ('📞', 'Telephone Receiver', True),
#   ('🏌️', 'Golf', True),
#   ('🇲🇻', 'flag Maldives', True),
#   ('📟', 'Beeper', True),
#   ('🇳🇿', 'flag New Zealand', True),
#   ('📠', 'Fax', True),
#   ('🌄', 'Sunrise Over Mountains', True),
#   ('🌬️', 'Wind Blowing Face', True),
#   ('🗿', 'Moai', True),
#   ('🇦🇲', 'flag Armenia', True),
#   ('⚾', 'Softball', True),
#   ('⏱️', 'Stopwatch', True),
#   ('🦀', 'Red Crab', True),
#   ('👺', 'Long Nose Face', True),
#   ('🐆', 'Jaguar', True),
#   ('🎅', 'Saint Nicholas', True),
#   ('🍰', 'Piece Of Cake', True),
#   ('🎂', 'Birthday Cake', True),
#   ('\U0001f924', 'Drooling Face', True),
#   ('🎛️', 'Control Knobs', True),
#   ('🔱', 'Pitchfork', True),
#   ('🚰', 'Thirst', True),
#   ('\U0001f930', 'Pregnant Woman', True),
#   ('\U0001f951', 'Avocado', True),
#   ('🚵', 'Mountain Bike', True),
#   ('🇩🇪', 'German Flag', True),
#   ('😼', 'Smirking Cat', True),
#   ('❕', 'White Exclamation Mark', True),
#   ('💾', 'Disk', True),
#   ('💎', 'Gem', True),
#   ('🏣', 'Japanese Post Office', True),
#   ('🏪', 'Kwik-E-Mart', True),
#   ('📠', 'Fax Machine', True),
#   ('👪', 'Family', True),
#   ('♠️', 'Spades', True),
#   ('🌠', 'When You Wish Upon A Star', True),
#   ('🇹🇻', 'Tuvaluan Flag', True),
#   ('🆖', 'NG', True),
#   ('🔷', 'Large Blue Diamond', True),
#   ('🍻', 'Cheers', True),
#   ('✌️', 'Peace', True),
#   ('🀄', 'Mahjong Tile', True),
#   ('✉️', '✉\\xa0Letter', True),
#   ('\U0001f943', 'Bourbon', True),
#   ('➰', 'Curling Loop', True),
#   ('⬆️', 'Up Arrow', True),
#   ('💃', 'Red Dress Woman', True),
#   ('🎐', 'Furin', True),
#   ('🤕', 'Bandaged Head', True),
#   ('👗', 'Gown', True),
#   ('🎽', 'Running Shirt With Sash', True),
#   ('📨', 'Envelope With Lines', True),
#   ('🍦', 'Mr Whippy', True),
#   ('🗑️', 'Wastebasket', True),
#   ('\U0001f91d', 'Shaking Hands', True),
#   ('💨', 'Dash Symbol', True),
#   ('🕐', 'Clock One O’Clock', True),
#   ('🔂', 'Circle Arrows With Number 1', True),
#   ('🚨', 'Flashing Light', True),
#   ('🐉', 'Dragon', True),
#   ('🚍', 'Front Of Bus', True),
#   ('🍻', 'Beers', True),
#   ('🐑', 'Ewe', True),
#   ('🌌', 'Universe', True),
#   ('☕', 'Tea', True),
#   ('🚿', 'Shower Head', True),
#   ('🐣', 'Hatching Chick', True),
#   ('🍉', 'Watermelon', True),
#   ('📨', 'Incoming Envelope', True),
#   ('⏩', 'Fast Forward', True),
#   ('🎥', 'Movie Camera', True),
#   ('🕞', 'Clock Three-Thirty', True),
#   ('♒', 'Aquarius', True),
#   ('🔑', 'Gold Key', True),
#   ('🎓', 'College', True),
#   ('🇨🇺', 'flag Cuba', True),
#   ('🐜', 'Bullant', True),
#   ('🆗', 'Okay', True),
#   ('🌡️', 'Hot Weather', True),
#   ('🇬🇲', 'Gambian\\xa0Flag', True),
#   ('🔟', 'Keycap Ten', True),
#   ('🇸🇸', 'flag South Sudan', True),
#   ('🇶🇦', 'flag Qatar', True),
#   ('👐', 'Open Hands Sign', True),
#   ('🔉', 'Reduce Volume', True),
#   ('🇵🇼', 'Palauan Flag', True),
#   ('🍭', 'Lollipop', True),
#   ('⚔️', 'Crossed Swords', True),
#   ('👄', 'Kissing Lips', True),
#   ('🅱️', 'Negative Squared Latin Capital Letter B', True),
#   ('🏴\U000e0067\U000e0062\U000e0073\U000e0063\U000e0074\U000e007f',
#    'flag Scotland (GB-SCT)',
#    True),
#   ('💈', 'Barber Shop', True),
#   ('\U0001f939\u200d♀️', 'Female Juggler', True),
#   ('🎀', 'Bow', True),
#   ('📄', 'Printed Page', True),
#   ('⬅️', 'Left Arrow', True),
#   ('🇪🇺', 'European Flag', True),
#   ('✂️', 'Black Scissors', True),
#   ('🏪', 'Corner Shop', True),
#   ('🌽', 'Corn', True),
#   ('📼', 'Videocassette', True),
#   ('🎥', 'Hollywood', True),
#   ('🚮', 'Put Litter in Its Place Symbol', True),
#   ('⏬', 'Black Down-Pointing Double Triangle', True),
#   ('📼', 'VCR', True),
#   ('🎱', '8 Ball', True),
#   ('🇧🇷', 'flag Brazil', True),
#   ('🐖', 'Pig', True),
#   ('✝️', 'Latin Cross', True),
#   ('📨', 'Envelope With Lines', True),
#   ('📹', 'Video Camera', True),
#   ('🐬', 'Dolphin', True),
#   ('✔️', 'Check', True),
#   ('🍠', 'Sweet Potato', True),
#   ('🍎', 'Red Apple', True),
#   ('😏', 'Suggestive Smile', True),
#   ('⛓️', 'Chains', True),
#   ('📈', 'Positive\\xa0Chart', True),
#   ('🙆\u200d♂️', 'Man Gesturing OK', True),
#   ('🍩', 'Donut', True),
#   ('🇪🇬', 'Egyptian Flag', True),
#   ('📁', 'Folder', True),
#   ('🎐', 'Wind Bell', True),
#   ('📍', 'Pin', True),
#   ('\U0001f5a4', 'Black Heart', True),
#   ('📈', 'Up Pointing Graph', True),
#   ('🍰', 'Strawberry Shortcake', True),
#   ('🐝', 'Bumble Bee', True),
#   ('🆗', 'OK', True),
#   ('🔬', 'Microscope', True),
#   ('🚼', 'Baby Symbol', True),
#   ('🇦🇪', 'Emirati Flag', True),
#   ('🚎', 'Trolleybus', True),
#   ('📜', 'Scroll', True),
#   ('🚱', 'No Water', True),
#   ('⚡', 'High Voltage Sign', True),
#   ('🍀', 'Four Leaf Clover', True),
#   ('🌻', 'Sunflower', True),
#   ('💺', 'Aeroplane Seat', True),
#   ('🇲🇨', 'flag Monaco', True),
#   ('🍚', 'Rice', True),
#   ('🐛', 'Caterpillar', True),
#   ('🇵🇸', 'flag Palestinian Territories', True),
#   ('🙍\u200d♀️', 'Woman Frowning', True),
#   ('🚥', 'Horizontal Traffic Light', True),
#   ('🍵', 'Matcha Green Tea', True),
#   ('🇹🇲', 'Turkmen Flag', True),
#   ('📝', 'Memo', True),
#   ('💖', 'Sparkly Heart', True),
#   ('🈹', '割', True),
#   ('🐩', 'Toy Poodle', True),
#   ('👔', 'Shirt And Tie', True),
#   ('🇦🇼', 'Aruban Flag', True),
#   ('🇪🇪', 'Estonian Flag', True),
#   ('🇬🇪', 'flag Georgia', True),
#   ('🇹🇼', 'Taiwanese Flag', True),
#   ('📆', 'Day Calendar', True),
#   ('😘', 'Face Throwing a Kiss', True),
#   ('💪', 'Feats of Strength', True),
#   ('🚗', 'Automobile', True),
#   ('❄️', 'Snow', True),
#   ('📎', 'Clippy', True),
#   ('🈯', 'Finger Point', True),
#   ('🔍', 'Search Icon', True),
#   ('🇲🇬', 'flag Madagascar', True),
#   ('🌍', 'World', True),
#   ('❎', 'Cross', True),
#   ('📃', 'Curly\\xa0Page', True),
#   ('🌩️', 'Cloud With Lightning', True),
#   ('🚇', 'Train', True),
#   ('☄️', 'Blue Beam', True),
#   ('🌌', 'Milky Way', True),
#   ('🇧🇦', 'flag Bosnia &amp; Herzegovina', True),
#   ('🍬', 'Lolly', True),
#   ('🍊', 'Orange', True),
#   ('🚺', 'Womens\\xa0Toilet', True),
#   ('👋', 'Hello', True),
#   ('💤', 'Sleeping Symbol', True),
#   ('🇺🇸', 'Regional Indicator Symbol Letters US', True),
#   ('🇸🇰', 'Slovak\\xa0Flag', True),
#   ('🕓', 'Clock Four O’Clock', True),
#   ('💮', 'Well Done Stamp', True),
#   ('😪', 'Snot Bubble', True),
#   ('🇻🇬', 'flag British Virgin Islands', True),
#   ('🙉', 'Monkey Covering Ears', True),
#   ('📋', 'Clipboard', True),
#   ('\U0001f93d\u200d♀️', 'Woman Playing Water Polo', True),
#   ('🚮', 'Put Litter In Trash', True),
#   ('➕', 'Heavy Plus Sign', True),
#   ('🔠', 'ABCD', True),
#   ('👵', 'Older Woman', True),
#   ('ℹ️', 'Info', True),
#   ('⛳', 'Golf Flag', True),
#   ('🃏', 'Joker Card', True),
#   ('🔔', 'Liberty Bell', True),
#   ('🇱🇹', 'flag Lithuania', True),
#   ('😽', 'Kissing Cat Face With Closed Eyes', True),
#   ('👰', 'Marriage', True),
#   ('🏊\u200d♂️', 'Man Swimming', True),
#   ('🏚️', 'Haunted House', True),
#   ('🇸🇦', 'flag Saudi Arabia', True),
#   ('➰', 'Curly Loop', True),
#   ('\U0001f921', 'Gary the Privacy Clown', True),
#   ('🌵', 'Desert', True),
#   ('🕶️', 'Dark Sunglasses', True),
#   ('🍤', 'Ebi Furai', True),
#   ('🎋', 'Tanabata', True),
#   ('🌎', 'World', True),
#   ('💥', 'Impact', True),
#   ('👞', 'Brown Shoe', True),
#   ('💎', 'Diamond', True),
#   ('🏓', 'Table Tennis Paddle and Ball', True),
#   ('☹️', 'Megafrown', True),
#   ('📔', 'Notebook With Decorative Cover', True),
#   ('👮\u200d♀️', 'Woman Police Officer', True),
#   ('🅿️', 'Negative Squared Latin Capital Letter P', True),
#   ('🌾', 'Ear of Rice', True),
#   ('🍿', 'Popcorn', True),
#   ('👩\u200d⚖️', 'Woman Judge', True),
#   ('🔦', 'Torch', True),
#   ('👩\u200d👩\u200d👦\u200d👦', 'Lesbian family', True),
#   ('\U0001f933', 'Selfie Hand', True),
#   ('📩', 'Insert In Envelope', True),
#   ('🧀', 'Cheese', True),
#   ('⚓', 'Anchor', True),
#   ('👂', 'Hearing', True),
#   ('🔪', 'Kitchen Knife', True),
#   ('🇸🇴', 'Somalian\\xa0Flag', True),
#   ('😗', ':-*', True),
#   ('😭', 'Sobbing', True),
#   ('🈸', 'Monkey', True),
#   ('🇧🇧', 'Barbadian Flag', True),
#   ('🎱', 'Magic 8 Ball', True),
#   ('®️', 'Registered', True),
#   ('🏰', 'Turrets', True),
#   ('▶️', 'Black Right-Pointing Triangle', True),
#   ('🇱🇧', 'flag Lebanon', True),
#   ('👝', 'Pouch', True),
#   ('☑️', 'Ballot Box With Check', True),
#   ('⚱️', 'Vase', True),
#   ('🇩🇬', 'flag Diego Garcia', True),
#   ('\U0001f985', 'Eagle', True),
#   ('🇬🇺', 'Guamanian Flag', True),
#   ('🚣', 'Rowboat', True),
#   ('🐊', 'Alligator', True),
#   ('❣️', 'Heavy Heart Exclamation Mark Ornament', True),
#   ('📅', 'July 17', True),
#   ('😤', 'Airing of Grievances', True),
#   ('💡', 'Idea', True),
#   ('🏌️', 'Golfer', True),
#   ('🕸️', 'Cobweb', True),
#   ('😊', 'Smile', True),
#   ('📛', 'Name Badge', True),
#   ('⌚', 'Watch', True),
#   ('🌵', 'Cactus', True),
#   ('🌍', 'Earth Globe Europe-Africa', True),
#   ('📢', 'PA System', True),
#   ('👋', 'Hand Wave', True),
#   ('🎸', 'Acoustic\\xa0Guitar', True),
#   ('👷\u200d♂️', 'Man Construction Worker', True),
#   ('⚖️', 'Scales', True),
#   ('🐭', 'Mouse', True),
#   ('🇱🇷', 'Liberian Flag', True),
#   ('🚣\u200d♂️', 'Man Rowing Boat', True),
#   ('🇸🇪', 'flag Sweden', True),
#   ('🍋', 'Yellow Fruit', True),
#   ('🚸', 'School Crossing', True),
#   ('🚢', 'Cruise', True),
#   ('🤘', 'Devil Fingers', True),
#   ('🐂', 'Ox', True),
#   ('👨\u200d👨\u200d👧\u200d👧', 'Gay family', True),
#   ('👱\u200d♀️', 'Blond-Haired Woman', True),
#   ('🔲', 'Black Square Button', True),
#   ('💿', 'CD ROM', True),
#   ('😱', 'Face Screaming in Fear', True),
#   ('📌', 'Thumb Tack', True),
#   ('⛈️', 'Thunder Cloud and Rain', True),
#   ('🇹🇬', 'flag Togo', True),
# ...
#   ('🍦', 'bioneer', False),
#   ('🐲', 'emmetts imaginings', False),
#   ('🅿️', 'mealiff ibizan maroofity', False),
#   ('🏊\u200d♂️', 'crimebuster', False),
#   ('👆', 'appssavvy parripak mabigat', False),
#   ('🗼', 'boeve unswerving inhabited', False),
#   ('🌙', 'ewire', False),
#   ('🆕', 'polartrec annacurra', False),
#   ('🙅\u200d♀️', 'metzbower', False),
#   ('🔏', 'tvc', False),
#   ('⚙️', 'ettredge cpib', False),
#   ('🚍', 'cfpsa vannatter', False),
#   ('🐛', 'oyarzo pogon ebitdac', False),
#   ('🚵\u200d♂️', 'kuiti spokersperson bestcompanies', False),
#   ('🇦🇸', 'crossover runes precertification', False),
#   ('😒', 'asmuch', False),
#   ('🐟', 'stiness plainsman there', False),
#   ('\U0001f93c', 'sclhs mitigation', False),
#   ('🌓', 'kathlene', False),
#   ('♻️', 'schils veritest', False),
#   ('㊙️', 'crescendoes', False),
#   ('🍈', 'westerford', False),
#   ('🇾🇹', 'maxwest sann', False),
#   ('🇮🇨', 'dasquie galjoen', False),
#   ('⛏️', 'tatis tebbutt', False),
#   ('📄', 'bgco', False),
#   ('⛰️', 'zurrer salivation', False),
#   ('🇲🇽', 'verwoerd teknologies', False),
#   ('🏨', 'strathclyde sombir redubbing', False),
#   ('\U0001f937\u200d♂️', 'solfotara', False),
#   ('❗', 'denark pornsawan cineram', False),
#   ('👑', 'miloscia sawal pickrum', False),
#   ('📑', 'guttilla avraham figa', False),
#   ('🙆\u200d♂️', 'thorobreds', False),
#   ('🎠', 'uzbeki dardar', False),
#   ('🌄', 'ghura', False),
#   ('🙆', 'appaiah marzola', False),
#   ('🌥️', 'hilborne lkt', False),
#   ('🛍️', 'jamgrass', False),
#   ('🎢', 'tinryland bhanumurthy', False),
#   ('🚜', 'sponenberg microspace branford', False),
#   ('🏴\u200d☠️', 'ukti corvairs', False),
#   ('🛄', 'wiebo', False),
#   ('🔑', 'sacosan', False),
#   ('🔓', 'aruvians changquan luiseno', False),
#   ('\U0001f6d1', 'ilogbo ssina orix', False),
#   ('🔜', 'denke abetifi kiyokazu', False),
#   ('⛳', 'textualist punishing tipp', False),
#   ('🕴️', 'tranquillizer', False),
#   ('🕋', 'dogbo', False),
#   ('🇨🇼', 'lysaker selznick', False),
#   ('↘️', 'bylsma', False),
#   ('♑', 'spaul klutznick infalling', False),
#   ('❇️', 'asterism', False),
#   ('👭', 'schlander provde kampai', False),
#   ('🏘️', 'chitkala', False),
#   ('👱\u200d♀️', 'zebro mediscience wilgen', False),
#   ('🏄', 'retravision embossment', False),
#   ('🏕️', 'vinzons elises', False),
#   ('✅', 'orphen', False),
#   ('❎', 'scuffing jancie brandegee', False),
#   ('🙆\u200d♀️', 'enology clarko kyivstar', False),
#   ('🌅', 'ysdo vizzoni mainy', False),
#   ('\U0001f948', 'fellbach adzharia disini', False),
#   ('😄', 'ojota sumukha', False),
#   ('🇹🇩', 'holdiay', False),
#   ('📋', 'kesman', False),
#   ('🔎', 'sexuals verbalized nortriptyline', False),
#   ('🇹🇱', 'soldini', False),
#   ('↘️', 'foriska', False),
#   ('🐾', 'scurti', False),
#   ('🗻', 'stairmasters klarberg', False),
#   ('🇨🇿', 'neubronner ferleger', False),
#   ('🌒', 'ovbc slutkin', False),
#   ('🚿', 'tarawera', False),
#   ('🇹🇷', 'dhore tarisai chamoru', False),
#   ('🍱', 'durward', False),
#   ('🛐', 'temne steede aerofoil', False),
#   ('⛺', 'hasibuan', False),
#   ('🌯', 'otjinene augenbraum', False),
#   ('🎗️', 'indexer', False),
#   ('🔵', 'mirja hbra hshs', False),
#   ('🇵🇷', 'akratitos', False),
#   ('🌕', 'sportran', False),
#   ('⛸️', 'mammadli chabin', False),
#   ('💂\u200d♂️', 'chapelfield pekinese ambulate', False),
#   ('🙀', 'topness curulla dioh', False),
#   ('🇮🇸', 'kaighan caracciolo', False),
#   ('📷', 'schanen onsite eigsti', False),
#   ('🌳', 'augustyn didin', False),
#   ('🛳️', 'july', False),
#   ('🍕', 'giscombe dificult', False),
#   ('🌸', 'navisphere auctiondrop schaeff', False),
#   ('🚘', 'federalist osanic', False),
#   ('📯', 'ruzich', False),
#   ('👇', 'albertis', False),
#   ('👨\u200d👨\u200d👧', 'redware khuram', False),
#   ('🙍\u200d♀️', 'gdss', False),
#   ('🏴', 'rodewald', False),
#   ('💑', 'plumondore kyzer wyzanowski', False),
#   ('🛩️', 'ostracising', False),
#   ('🇨🇼', 'defrenn', False),
#   ('👨\u200d🚒', 'giesbers coiffard financi', False),
#   ('🇳🇴', 'budhiraja', False),
#   ('🎩', 'minkow novasep apublic', False),
#   ('➕', 'ejari sabots', False),
#   ('\U0001f926', 'wyeths alsopp', False),
#   ('😗', 'suporta qualcomm', False),
#   ('🇳🇷', 'rasoi bxc trademart', False),
#   ('💔', 'carmit federa', False),
#   ('🚓', 'sheats backtracks', False),
#   ('🌒', 'geoffray safta yearby', False),
#   ('😱', 'wellmans seatbelts odhimabo', False),
#   ('🖌️', 'saguaros becci autoworker', False),
#   ('👩\u200d👩\u200d👧', 'simplyswitch avvai', False),
#   ('😴', 'mckennedy lumigent lipeles', False),
#   ('👣', 'novitec furbush', False),
#   ('📶', 'ihh', False),
#   ('🇪🇺', 'berezovskaya', False),
#   ('🇱🇦', 'duzgun insari probabilities', False),
#   ('🎾', 'inxitu washlands', False),
#   ('💵', 'prv rapeseed', False),
#   ('🗾', 'plusnet barbarity', False),
#   ('👯\u200d♀️', 'ruaan digl', False),
#   ('☔', 'hlhs shalman', False),
#   ('🇷🇪', 'ksg semick', False),
#   ('💁', 'cretney cloudprint', False),
#   ('🌠', 'aekyung', False),
#   ('🇯🇪', 'gutwrench exotics intimex', False),
#   ('🎪', 'bevi lins', False),
#   ('🇻🇺', 'bunster walleye', False),
#   ('🐽', 'webintelligence catagorized', False),
#   ('😽', 'hiab cabotage', False),
#   ('👨\u200d👨\u200d👦', 'dimes', False),
#   ('⌚', 'walerius aurcana', False),
#   ('💁\u200d♀️', 'uzan', False),
#   ('🇲🇻', 'tracye serekunda', False),
#   ('🎵', 'zuccarelli farroll louisianans', False),
#   ('👩\u200d👦\u200d👦', 'geekily biol nandina', False),
#   ('🖥️', 'marchisano', False),
#   ('🎤', 'cyberpark gigaliters', False),
#   ('🇦🇼', 'zbc unsprayed', False),
#   ('\U0001f93c\u200d♂️', 'collotype', False),
#   ('🐊', 'cwah warora', False),
#   ('🖋️', 'herko fior', False),
#   ('🌱', 'pheifer laverne', False),
#   ('😌', 'jiburi powerpop', False),
#   ('🇧🇴', 'srta madiot', False),
#   ('🇳🇿', 'ermp', False),
#   ('🇦🇸', 'pief', False),
#   ('🇳🇵', 'tanmay orbaker', False),
#   ('🇲🇦', 'heflin ragib', False),
#   ('☸️', 'teutons tanzanite yarus', False),
#   ('🗻', 'sence sudderth', False),
#   ('🏨', 'suncity gazala doetch', False),
#   ('🇨🇻', 'tobermory legate', False),
#   ('👩\u200d👧\u200d👦', 'rosebel zaake', False),
#   ('💝', 'flixwagon bandeira koske', False),
#   ('🎿', 'pockmark', False),
#   ('🌮', 'galow alabaman', False),
#   ('😔', 'topolino', False),
#   ('🔹', 'shinefield houlston fastin', False),
#   ('🇬🇦', 'shotley gream bramer', False),
#   ('🛡️', 'momper kyoshin', False),
#   ('♥️', 'mapu deibert', False),
#   ('👩\u200d🔬', 'mandovi preganancy hollenbeak', False),
#   ('🐼', 'nanomembrane', False),
#   ('⌛', 'naween', False),
#   ('☮️', 'etoundi', False),
#   ('👣', 'rathgar', False),
#   ('🕐', 'elrio marielena', False),
#   ('🇱🇮', 'gangseo lectio sleidd', False),
#   ('🚴\u200d♂️', 'elijah mystaru pugsley', False),
#   ('🚐', 'kumtor bubye', False),
#   ('\U0001f935', 'hartmoor mongo', False),
#   ('💘', 'kalamansi', False),
#   ('📿', 'wordgirl keqin', False),
#   ('🖊️', 'saag', False),
#   ('🚶\u200d♀️', 'reppa', False),
#   ('🇨🇼', 'verlaque conedison', False),
#   ('👱\u200d♀️', 'gulal', False),
#   ('😼', 'mostazafan crebs', False),
#   ('👫', 'lagomichos severini ipha', False),
#   ('🇺🇦', 'bugh cdtc', False),
#   ('🇮🇹', 'insubria preszcator irondequoit', False),
#   ('📅', 'passino mortuaries', False),
#   ('🇦🇽', 'arwon', False),
#   ('🚋', 'gulsum durleigh', False),
#   ('🇹🇻', 'jaylib sonik', False),
#   ('🈵', 'gratigny', False),
#   ('👨\u200d👧', 'salterbeck', False),
#   ('🌌', 'margoshes rodbard', False),
#   ('👩\u200d✈️', 'chayne', False),
#   ('🇲🇵', 'luyen schlitt plaza', False),
#   ('🚐', 'polyurethanes attila', False),
#   ('🚷', 'moralis', False),
#   ('💸', 'fortey hexagonal', False),
#   ('🍅', 'butiama', False),
#   ('↩️', 'cinespace beatnuts atanarjuat', False),
#   ('\U0001f939\u200d♂️', 'designated', False),
#   ('🇹🇫', 'stakhanovite', False),
#   ('👚', 'koshimoto', False),
#   ('🎳', 'golpu explitive donkoh', False),
#   ('\U0001f953', 'dulak', False),
#   ('🇭🇹', 'quaoar', False),
#   ('💪', 'aser crestfallen njcf', False),
#   ('🌵', 'museglobal bajec', False),
#   ('🇧🇸', 'peregrina grandiloquently chahine', False),
#   ('🔞', 'highfalutin', False),
#   ('🍺', 'doorstaff', False),
#   ('🇵🇰', 'glebov', False),
#   ('🚅', 'delorie bochic drumbeg', False),
#   ('🚛', 'mwaluka climax cerina', False),
#   ('⛑️', 'noobs traderplanet hotwalkers', False),
#   ('🇬🇬', 'calixtro nevans', False),
#   ('👑', 'climatecare goodfellows', False),
#   ('〽️', 'vimto vssc kruhly', False),
#   ('🇼🇸', 'forrestal oldway sunita', False),
#   ('🚝', 'hawf', False),
#   ('\U0001f57a', 'nitot napal', False),
#   ('🕐', 'ambling', False),
#   ('🍵', 'schlief', False),
#   ('\U0001f937', 'hestermann saori', False),
#   ('♉', 'kobayakawa phlpp', False),
#   ('🇲🇰', 'pruf ekho jaworowicz', False),
#   ('👨\u200d👦', 'comentarios huntercombe labbad', False),
#   ('👨\u200d🎤', 'naral', False),
#   ('⛹️', 'ehess', False),
#   ('🌽', 'telmarines', False),
#   ('🚞', 'dippenaar', False),
#   ('\U0001f93c', 'zarzour toji arguin', False),
#   ('🚣\u200d♀️', 'kadawatha', False),
#   ('👨\u200d🚒', 'arkdale', False),
#   ('🙅\u200d♀️', 'sejersen', False),
#   ('🇭🇲', 'cruisecritic mukhopadhaya', False),
#   ('⬛', 'edginton', False),
#   ('🎚️', 'myraid balyo', False),
#   ('🚂', 'ungashick hydromet', False),
#   ('☝️', 'kritscher aphios slfp', False),
#   ('🙇\u200d♀️', 'arcangeli dace', False),
#   ('🙅\u200d♂️', 'concilla', False),
#   ('👑', 'peveto sanitarian fibrocytes', False),
#   ('🏰', 'geraci rasar', False),
#   ('💜', 'banas rodriquenz', False),
#   ('🎉', 'weirded', False),
#   ('🚔', 'ohrv rampaul', False),
#   ('🐬', 'hypercar polycythemia', False),
#   ('⛱️', 'coordinating somit comand', False),
#   ('🍠', 'koloy wotm', False),
#   ('🔒', 'forecaster', False),
#   ('🇲🇼', 'winrock pseudoephedrine kamakea', False),
#   ('👩\u200d👩\u200d👦', 'speedcast jacquemod forswearing', False),
#   ('\U0001f944', 'polleit oyedeji usni', False),
#   ('🙈', 'biosquare', False),
#   ('🎧', 'teaff realtysellers drommond', False),
#   ('💼', 'chemplast haycook okuru', False),
#   ('📼', 'dallied zenanko cossipore', False),
#   ('👨\u200d👩\u200d👧\u200d👧', 'mahon bibb', False),
#   ('🏃\u200d♂️', 'eclipselink nado indifferentism', False),
#   ('🍭', 'tandoor', False),
#   ('🐱', 'glossner raof', False),
#   ('☣️', 'housemen', False),
#   ('💠', 'palyers', False),
#   ('🗝️', 'youtsey unai anastassiadis', False),
#   ('💆\u200d♂️', 'rajvansh warmuth', False),
#   ('🌞', 'strategist', False),
#   ('🇨🇩', 'bepko pictorialist', False),
#   ('🐳', 'daydreamer reinhold', False),
#   ('✝️', 'xmsr brushpile visitin', False),
#   ('💑', 'covariates', False),
#   ('🇧🇧', 'saadian', False),
#   ('🇸🇽', 'dequadros mcconaghy glerum', False),
#   ('🎭', 'rolt potshot neng', False),
#   ('🍈', 'wimpie', False),
#   ('🇦🇮', 'poojappura grapeview samih', False),
#   ('🎙️', 'seshiah cherrybrook folga', False),
#   ('🗜️', 'tolfrey irawat', False),
#   ('📰', 'imsland harai durnian', False),
#   ('🎼', 'kennet stimulation', False),
#   ('🇲🇰', 'prank', False),
#   ('🚤', 'lingnan', False),
#   ('\U0001f6f5', 'moosejaw durotoye', False),
#   ('🛏️', 'tankard rifkin', False),
#   ('🚚', 'emedicine', False),
#   ('📙', 'appgeo resalable', False),
#   ('🤗', 'tevez castellane', False),
#   ('✋', 'coordes rohan', False),
#   ('🌃', 'wvhs monocoque', False),
#   ('❕', 'ahmedabad igueben kalmati', False),
#   ('8️⃣', 'hyres ingemi clpoa', False),
#   ('🇰🇬', 'complicite', False),
#   ('🇦🇬', 'kwgn croteam millhoff', False),
#   ('⚔️', 'mandini onsale olys', False),
#   ('🚥', 'washingtonia dineshkumar', False),
#   ('🍃', 'sensecam', False),
#   ('🏕️', 'cthulu raheel bennie', False),
#   ('✔️', 'magedson expressjet', False),
#   ('👩\u200d🍳', 'ventrone chrane', False),
#   ('👨\u200d🏭', 'forguites taltran', False),
#   ('◾', 'dybdal', False),
#   ('🇷🇸', 'bienias woyzbun', False),
#   ('📑', 'irethorrou', False),
#   ('🍉', 'trudy chomping crabtree', False),
#   ('💼', 'assaidi fillibuster boulier', False),
#   ('🌧️', 'rajsich subregions', False),
#   ('💅', 'skinnyman', False),
#   ('🍆', 'nimmitabel poortman', False),
#   ('🇸🇧', 'brookin', False),
#   ('⛵', 'mogadishu', False),
#   ('⚓', 'akihito', False),
#   ('🇲🇲', 'goess totori maksak', False),
#   ('☂️', 'stpi illamasqua vellev', False),
#   ('💁\u200d♂️', 'changelings undeserved idwal', False),
#   ('🇻🇪', 'tshepho verzwyvelt pcb', False),
#   ('\U0001f93d', 'gridcom hansohn', False),
#   ('♨️', 'guizot', False),
#   ('\U0001f95c', 'jugglery', False),
#   ('😮', 'konken allyn', False),
#   ('↪️', 'labeltag', False),
#   ('☑️', 'lpu', False),
#   ('🐰', 'myette wahhab grayci', False),
#   ('🌟', 'hydrino shige zimet', False),
#   ('🔍', 'detolla comeptition manikchak', False),
#   ('🇦🇪', 'appell gwyne', False),
#   ('🚍', 'heise ulleval uraniferous', False),
#   ('🚘', 'makurdi ostrander', False),
#   ('😡', 'kamelmacher vavassori unreacted', False),
#   ('🙊', 'payrise tymann winnies', False),
#   ('🗜️', 'muggs shipston halvey', False),
#   ('🈸', 'spoonire petronor ellender', False),
#   ('🏬', 'squillaciotti amorousness', False),
#   ('🎱', 'greiss nohfc', False),
#   ('🇲🇻', 'sture forgette quasney', False),
#   ('🌕', 'fazly szulczewski', False),
#   ('✝️', 'noael mattes doeskin', False),
#   ('🇰🇮', 'ferbert', False),
#   ('💂', 'bernheisel', False),
#   ('📐', 'superpass hengemuhle witkin', False),
#   ('🎆', 'pindy ncpe', False),
#   ('👾', 'dailykos ucmas qqqq', False),
#   ('🙋\u200d♀️', 'simec', False),
#   ('🚈', 'summerlike gawping rotoscoping', False),
#   ('👷\u200d♀️', 'alferes kepchar rojstaczer', False),
#   ('©️', 'danczak cseh shunga', False),
#   ('🐒', 'wqs anowar', False),
#   ('🍣', 'shahat yeagy milingimbi', False),
#   ('🍰', 'kpoi pasarow raimunda', False),
#   ('♓', 'umping', False),
#   ('♿', 'bocchini gayoso', False),
#   ('🙇\u200d♀️', 'sheffielder veer szott', False),
#   ('📷', 'kodam', False),
#   ('🕙', 'swansbrough supertax hoeta', False),
#   ('🛩️', 'apacible zstn larigakis', False),
#   ('\U0001f956', 'noroian knavery janszen', False),
#   ('📙', 'revalving jameelah govguam', False),
#   ('🇩🇬', 'wapakoneta tropiano', False),
#   ('⏬', 'habersetzer guaderrama', False),
#   ('⚒️', 'redlining wankhade warhola', False),
#   ('\U0001f93d\u200d♂️', 'rvsc tunzi', False),
#   ('‼️', 'bewell shunichiro', False),
#   ('🗃️', 'marzinotto', False),
#   ('⏪', 'haileybury', False),
#   ('🚴\u200d♀️', 'staffier', False),
#   ('8️⃣', 'bicholim umsinga imperturbable', False),
#   ('🛐', 'borley nanina', False),
#   ('🆑', 'cordonned oleg hpmc', False),
#   ('1️⃣', 'winterguard', False),
#   ('💠', 'ornato gatchalian', False),
#   ('🌧️', 'kedumim', False),
#   ('🚷', 'cytogen raysha zednick', False),
#   ('🌽', 'ozyildirim arbico turbanator', False),
#   ('💋', 'gavrieli raeesani', False),
#   ('👬', 'sarota', False),
#   ('🏖️', 'asselstine longue monent', False),
#   ('🌝', 'shipbroking agonistic dinhi', False),
#   ('🇨🇱', 'trfu onsight roadholding', False),
#   ('👩\u200d🍳', 'ekoku wallarab', False),
#   ('🇦🇶', 'mhip', False),
#   ('🇧🇶', 'ensnarled cloues', False),
#   ('📨', 'verio meziere', False),
#   ('🔜', 'indigestion', False),
#   ('🖲️', 'datagrid', False),
#   ('🔟', 'aguirres wqcd kenopic', False),
#   ('♉', 'artistdirect', False),
#   ('📉', 'prochain', False),
#   ('🍶', 'edag', False),
#   ('\U0001f6f5', 'nanxing decristo cattern', False),
#   ('🚒', 'suitehotel actigraphs', False),
#   ('📇', 'gooty crimestopper kalakar', False),
#   ('🆎', 'totalcare infotonics', False),
#   ('🎡', 'dlt kanwaljeet', False),
#   ('⚖️', 'jalolov boysenberries kalihati', False),
#   ('🏁', 'verneuil', False),
#   ('🐇', 'djilas', False),
#   ('🇹🇴', 'sparby warther', False),
#   ('🉑', 'barrica beletsky keijiro', False),
#   ('👑', 'linscomb galati hempenstall', False),
#   ('⛸️', 'paesano', False),
#   ('🔓', 'sakashta', False),
#   ('⚽', 'olusanya mjm njrc', False),
#   ('🐍', 'sitoa unluckier', False),
#   ('📴', 'sygulla bermeo', False),
#   ('\U0001f950', 'lagredelle', False),
#   ('🐾', 'buyrate valdivieso jingdezhen', False),
#   ('🎊', 'huebel undid deplanche', False),
#   ('🙎', 'slar hazelman', False),
#   ('🔏', 'introductory chironomid', False),
#   ('💥', 'beighley', False),
#   ('😏', 'grochow martand', False),
#   ('🌤️', 'bouffants rondel tejal', False),
#   ('🔅', 'girijababu nuschler', False),
#   ('🈸', 'anexinet', False),
#   ('⬅️', 'rumblin briscos imel', False),
#   ('📗', 'cardium suprun alcomo', False),
#   ('🐸', 'geschichte', False),
#   ('💨', 'atterdag msaps falintil', False),
#   ('🦄', 'rukoko lisius evergood', False),
#   ('🇬🇦', 'meritdirect', False),
#   ('🇪🇭', 'meshack elystan talanoa', False),
#   ('🇦🇴', 'alado', False),
#   ('🏩', 'pinkstone wigi', False),
#   ('📕', 'leeching', False),
#   ('🚒', 'welcombe', False),
#   ('😉', 'holiday hammerax kneepkens', False),
#   ('🇹🇷', 'krafla econiq hubbartt', False),
#   ('\U0001f93c\u200d♂️', 'accubid winns', False),
#   ('🏙️', 'permissioning datacert', False),
#   ...])

# %%
random.shuffle(positive_samples)
random.shuffle(negative_samples)
with open("../data/ref_positive.txt", "w") as file:
    for i in range(len(positive_samples)):
        for j in range(3):
            file.write(str(positive_samples[i][j]))
            file.write('\t')
        file.write('\n')

with open("../data/ref_negative.txt", "w") as file:
    for i in range(len(negative_samples)):
        for j in range(3):
            file.write(str(negative_samples[i][j]))
            file.write('\t')
        file.write('\n')
